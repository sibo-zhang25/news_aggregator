# %%
# %run functions

# %%
api_key ='6adfdd5a094c46daa53ea3bbb74379a5'
result = getenews(api_key)

# %%
result[1].display()
# Out:
# Title:US launches 'powerful strikes' against Islamic State in Nigeria, says Trump - BBC
# Author:
# Published at 2025-12-26T04:17:47Z on BBC News
# Content:President Donald Trump has said the US launched a "powerful and deadly strike" against the Islamic State (IS) group in north-western Nigeria.   The US leader described IS as " terrorist scum", accusi… [+4063 chars]
#
# Link to the original news page: https://www.bbc.com/news/articles/cj69j8l918do

# %%
result[3].display()
# Out:
# Title:Thursday Night Football: Chiefs lead Broncos 7-6 at halftime - NBC Sports
# Author:Charean Williams
# Published at 2025-12-26T02:30:57Z on NBCSports.com
# Content:The Chiefs are eliminated from playoff contention and are playing their third-string quarterback. That hasnt stopped them from making things hard on the Broncos.  The Chiefs lead the Broncos 7-6 at h… [+999 chars]
#
# Link to the original news page: https://www.nbcsports.com/nfl/profootballtalk/rumor-mill/news/thursday-night-football-chiefs-lead-broncos-7-6-at-halftime
